# %%
import pandas as pd
import os
import os
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import pandas as pd
import glob
import datetime
import random
import matplotlib.pyplot as plt
import future

# %%
path_proj = r'C:/Users/loren/sptrans_project/docs_sptrans_tcc/projecao_populacional/projecao_populacional.csv'
path_distrito = r'C:/Users/loren/sptrans_project/docs_sptrans_tcc/projecao_populacional/tb_distritos.csv'
projecao = pd.read_csv(path_proj)
distritos = pd.read_csv(path_distrito)

# %%
projecao.head()
# Out:
#    mun_id  dist_id  ra_id  rg_id  rm_id  dir_id   ano   FH1   FH2   FH3  ...  \
# 0     NaN  80001.0    NaN    NaN    NaN     NaN  2011  2108  2031  2338  ...
# 1     NaN  80001.0    NaN    NaN    NaN     NaN  2012  2203  2014  2249  ...
# 2     NaN  80001.0    NaN    NaN    NaN     NaN  2013  2300  1996  2163  ...
# 3     NaN  80001.0    NaN    NaN    NaN     NaN  2014  2401  1977  2080  ...
# 4     NaN  80001.0    NaN    NaN    NaN     NaN  2015  2503  1957  1999  ...
#
#    FE17  FE18  FE19  FE20  FE21  FE22  FE23  PURB  PRUR    DOM
# 0  3348  1586   798  3341  3682  2884  2091   NaN   NaN  28709
# 1  3516  1603   794  3264  3573  2848  2051   NaN   NaN  28763
# 2  3689  1619   788  3189  3465  2812  2011   NaN   NaN  28816
# 3  3871  1632   783  3114  3360  2775  1970   NaN   NaN  28867
# 4  4054  1647   777  3037  3258  2737  1930   NaN   NaN  28918
#
# [5 rows x 49 columns]

# %%
distritos.head()
# Out:
#    dist_id          dist_desc
# 0    80001          Água Rasa
# 1    80002  Alto de Pinheiros
# 2    80003         Anhanguera
# 3    80004         Aricanduva
# 4    80005        Artur Alvim

# %%
all = projecao.join(distritos.set_index('dist_id'), on='dist_id')

all.head()
# Out:
#    mun_id  dist_id  ra_id  rg_id  rm_id  dir_id   ano   FH1   FH2   FH3  ...  \
# 0     NaN  80001.0    NaN    NaN    NaN     NaN  2011  2108  2031  2338  ...
# 1     NaN  80001.0    NaN    NaN    NaN     NaN  2012  2203  2014  2249  ...
# 2     NaN  80001.0    NaN    NaN    NaN     NaN  2013  2300  1996  2163  ...
# 3     NaN  80001.0    NaN    NaN    NaN     NaN  2014  2401  1977  2080  ...
# 4     NaN  80001.0    NaN    NaN    NaN     NaN  2015  2503  1957  1999  ...
#
#    FE18  FE19  FE20  FE21  FE22  FE23  PURB  PRUR    DOM  dist_desc
# 0  1586   798  3341  3682  2884  2091   NaN   NaN  28709  Água Rasa
# 1  1603   794  3264  3573  2848  2051   NaN   NaN  28763  Água Rasa
# 2  1619   788  3189  3465  2812  2011   NaN   NaN  28816  Água Rasa
# 3  1632   783  3114  3360  2775  1970   NaN   NaN  28867  Água Rasa
# 4  1647   777  3037  3258  2737  1930   NaN   NaN  28918  Água Rasa
#
# [5 rows x 50 columns]

# %%
fig, ax = plt.subplots(figsize=(13,5))
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

all.groupby(['ano']).sum()['FH6'].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='ano'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(x="ano", y="FM16", data=projecao)
plt.xticks(rotation=0)
plt.title('projecao')
plt.show()

# %%
all = all.groupby(['ano']).sum(["FM16"])

all.head()
# Out:
#             mun_id    dist_id     ra_id     rg_id    rm_id  dir_id      FH1  \
# ano
# 2011  2.276010e+09  7684656.0  443710.0  436807.0  45903.0  6257.0  1760665
# 2012  2.276010e+09  7684656.0  443710.0  436807.0  73086.0  6267.0  1800306
# 2013  2.276010e+09  7684656.0  443710.0  436807.0  73086.0  6267.0  1840275
# 2014  2.276010e+09  7684656.0  444126.0  436977.0  91956.0  6267.0  1880561
# 2015  2.276010e+09  7684656.0  444126.0  436977.0  91956.0  6267.0  1921269
#
#           FH2      FH3      FH4  ...     FE17     FE18    FE19     FE20  \
# ano                              ...
# 2011  1814607  2064471  2100588  ...  2782527  1352970  692603  2968632
# 2012  1787749  2005309  2114195  ...  2850903  1358426  687036  2898271
# 2013  1760597  1947140  2127130  ...  2920045  1363225  681195  2828152
# 2014  1733205  1889905  2139557  ...  2989805  1367515  675125  2758279
# 2015  1705712  1833747  2151044  ...  3060409  1371306  668889  2688875
#
# ...

# %%
fig = plt.figure() # Create matplotlib figure

ax = fig.add_subplot(211) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.3

all.FH6.plot(kind='bar', color='red', ax=ax, width=width, position=1)
all.FE17.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

ax.set_ylabel('Amount')
ax2.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
tb = all[["FH5","FH6","FM4","FM5","FM6","FM7"]]

# %%
import matplotlib.pyplot as plt
(tb/tb.iloc[0]*100).plot(figsize=(15,5))
plt.ylabel('crescimento populacional')
plt.xlabel('ano')
plt.show()
